# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\admin\anaconda3\lib\site-packages (from scipy) (1.25.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\admin\anaconda3\lib\site-packages (0.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
mushroom = fetch_ucirepo(id=73)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns
sns.set()
import pickle
from sklearn.preprocessing import LabelEncoder
from autoimpute.imputations import SingleImputer,MultipleImputer

# %%
# Convert the 'features' data into a DataFrame
mushroom_df = pd.DataFrame(mushroom['data']['original'])

# %%
mushroom_df.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0         n          k           e  ...                      w
# 1         b          k           e  ...                      w
# 2         b          n           e  ...                      w
# 3         n          n           e  ...                      w
# 4         b          k           t  ...                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color population habitat poisonous
# 0                 k          s       u         p
# 1                 n          n       g         e
# 2                 n          n       m         e
# 3                 k          s       u         p
# 4                 n          a       g         e
#
# [5 rows x 23 columns]

# %%
mushroom_df.iloc[0]
# Out:
# cap-shape                   x
# cap-surface                 s
# cap-color                   n
# bruises                     t
# odor                        p
# gill-attachment             f
# gill-spacing                c
# gill-size                   n
# gill-color                  k
# stalk-shape                 e
# stalk-root                  e
# stalk-surface-above-ring    s
# stalk-surface-below-ring    s
# stalk-color-above-ring      w
# stalk-color-below-ring      w
# veil-color                  w
# ring-number                 o
# ring-type                   p
# spore-print-color           k
# population                  s
# habitat                     u
# poisonous                   p
# Name: 0, dtype: object

# %% [markdown]
# Data Description: This dataset describes mushrooms in terms of their physical characteristics. They are classified into: poisonous or edible.
#
# 1. cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2. cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# 3. cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r, pink=p,purple=u,red=e,white=w,yellow=y
# 4. bruises?: bruises=t,no=f
# 5. odor: almond=a,anise=l,creosote=c,fishy=y,foul=f, musty=m,none=n,pungent=p,spicy=s
# 6. gill-attachment: attached=a,descending=d,free=f,notched=n
# 7. gill-spacing: close=c,crowded=w,distant=d
# 8. gill-size: broad=b,narrow=n
# 9. gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e, white=w,yellow=y
# 10. stalk-shape: enlarging=e,tapering=t
# 11. stalk-root: bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,rooted=r,missing=?
# 12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
# 14. stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 15. stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y
# 16. veil-type: partial=p,universal=u
# 17. veil-color: brown=n,orange=o,white=w,yellow=y
# 18. ring-number: none=n,one=o,two=t
# 19. ring-type: cobwebby=c,evanescent=e,flaring=f,large=l, none=n,pendant=p,sheathing=s,zone=z
# 20. spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r, orange=o,purple=u,white=w,yellow=y
# 21. population: abundant=a,clustered=c,numerous=n, scattered=s,several=v,solitary=y
# 22. habitat: grasses=g,leaves=l,meadows=m,paths=p, urban=u,waste=w,woods=d

# %%
mushroom_df['poisonous'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
mushroom_df.describe()
# Out:
#        cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count       8124        8124      8124    8124  8124            8124
# unique         6           4        10       2     9               2
# top            x           y         n       f     n               f
# freq        3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color stalk-shape  ...  \
# count          8124      8124       8124        8124  ...
# unique            2         2         12           2  ...
# top               c         b          b           t  ...
# freq           6812      5612       1728        4608  ...
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                         w                      w         p          w
# freq                     4464                   4384      8124       7924
#
#        ring-number ring-type spore-print-color population habitat poisonous
# count         8124      8124              8124       8124    8124      8124
# unique           3         5                 9          6       7         2
# top              o         p                 w          v       d         e
# freq          7488      3968              2388       4040    3148      4208
#
# [4 rows x 23 columns]

# %%
mushroom_df.isna().sum()
# Out:
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# poisonous                      0
# dtype: int64

# %%
mushroom_df['stalk-root']
# Out:
# 0         e
# 1         c
# 2         c
# 3         e
# 4         e
#        ...
# 8119    NaN
# 8120    NaN
# 8121    NaN
# 8122    NaN
# 8123    NaN
# Name: stalk-root, Length: 8124, dtype: object

# %% [markdown]
# There are 2480 missing values in "stalk-root" column. Let's replace such values with numpy "nan" so that we can handle the missing values.

# %%
mushroom_df['stalk-root'] = mushroom_df['stalk-root'].replace('NaN',np.nan)

# %% [markdown]
# Great! now we can see the missing values in the stalk-root column. we will impute these missing values.

# %%
for column in mushroom_df.columns:
    print(column,mushroom_df[column].nunique())
# Out:
# cap-shape 6
# cap-surface 4
# cap-color 10
# bruises 2
# odor 9
# gill-attachment 2
# gill-spacing 2
# gill-size 2
# gill-color 12
# stalk-shape 2
# stalk-root 4
# stalk-surface-above-ring 4
# stalk-surface-below-ring 4
# stalk-color-above-ring 9
# stalk-color-below-ring 9
# veil-type 1
# veil-color 4
# ring-number 3
# ring-type 5
# spore-print-color 9
# population 6
# habitat 7
# poisonous 2

# %% [markdown]
# Notice that "veil-type" column has only one unique category. This column won't give much information ,so let's drop it.

# %%
mushroom_df = mushroom_df.drop(['veil-type'],axis=1)

# %% [markdown]
# We will start with imputing the missing values. We will use "autoImputer" package. It provides various techniques to impute missing values. We will use Single Imputer here.

# %%
pip install autoimpute
# Out:
# Requirement already satisfied: autoimpute in c:\users\admin\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (1.25.2)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (1.11.1)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (2.0.3)
# Requirement already satisfied: statsmodels in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (0.14.0)
# Requirement already satisfied: xgboost in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (2.0.1)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (1.3.0)
# Requirement already satisfied: pymc in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (5.9.1)
# Requirement already satisfied: seaborn in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (0.12.2)
# Requirement already satisfied: missingno in c:\users\admin\anaconda3\lib\site-packages (from autoimpute) (0.5.2)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\lib\site-packages (from missingno->autoimpute) (3.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas->autoimpute) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas->autoimpute) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas->autoimpute) (2023.3)
# Requirement already satisfied: arviz>=0.13.0 in c:\users\admin\anaconda3\lib\site-packages (from pymc->autoimpute) (0.16.1)
# Requirement already satisfied: cachetools>=4.2.1 in c:\users\admin\anaconda3\lib\site-packages (from pymc->autoimpute) (5.3.2)
# Requirement already satisfied: cloudpickle in c:\users\admin\anaconda3\lib\site-packages (from pymc->autoimpute) (2.2.1)
# Requirement already satisfied: fastprogress>=0.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pymc->autoimpute) (1.0.3)
# Requirement already satisfied: pytensor<2.18,>=2.17.0 in c:\users\admin\anaconda3\lib\site-packages (from pymc->autoimpute) (2.17.3)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\admin\anaconda3\lib\site-packages (from pymc->autoimpute) (4.7.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->autoimpute) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn->autoimpute) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels->autoimpute) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels->autoimpute) (23.1)
# Requirement already satisfied: setuptools>=60.0.0 in c:\users\admin\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc->autoimpute) (68.0.0)
# Requirement already satisfied: xarray>=0.21.0 in c:\users\admin\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc->autoimpute) (2023.6.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc->autoimpute) (1.2.0)
# Requirement already satisfied: xarray-einstats>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from arviz>=0.13.0->pymc->autoimpute) (0.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->missingno->autoimpute) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->missingno->autoimpute) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->missingno->autoimpute) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->missingno->autoimpute) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->missingno->autoimpute) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib->missingno->autoimpute) (3.0.9)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels->autoimpute) (1.16.0)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from pytensor<2.18,>=2.17.0->pymc->autoimpute) (3.9.0)
# Requirement already satisfied: etuples in c:\users\admin\anaconda3\lib\site-packages (from pytensor<2.18,>=2.17.0->pymc->autoimpute) (0.3.9)
# Requirement already satisfied: logical-unification in c:\users\admin\anaconda3\lib\site-packages (from pytensor<2.18,>=2.17.0->pymc->autoimpute) (0.4.6)
# Requirement already satisfied: miniKanren in c:\users\admin\anaconda3\lib\site-packages (from pytensor<2.18,>=2.17.0->pymc->autoimpute) (1.0.3)
# Requirement already satisfied: cons in c:\users\admin\anaconda3\lib\site-packages (from pytensor<2.18,>=2.17.0->pymc->autoimpute) (0.4.6)
# Requirement already satisfied: h5py in c:\users\admin\anaconda3\lib\site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc->autoimpute) (3.9.0)
# Requirement already satisfied: toolz in c:\users\admin\anaconda3\lib\site-packages (from logical-unification->pytensor<2.18,>=2.17.0->pymc->autoimpute) (0.12.0)
# Requirement already satisfied: multipledispatch in c:\users\admin\anaconda3\lib\site-packages (from logical-unification->pytensor<2.18,>=2.17.0->pymc->autoimpute) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
mushroom_df['stalk-root'] = mushroom_df['stalk-root'].astype('category')

# %%
impute = SingleImputer(strategy='categorical')

# %%
impute.fit(mushroom_df)
# Out:
# SingleImputer(strategy='categorical')

# %%
new_data =impute.transform(mushroom_df)

# %%
new_data
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# 2               c         b          n           e  ...
# 3               c         n          n           e  ...
# 4               w         b          k           t  ...
# ...           ...       ...        ...         ...  ...
# 8119            c         b          y           e  ...
# 8120            c         b          y           e  ...
# 8121            c         b          n           e  ...
# 8122            c         n          b           t  ...
# 8123            c         b          y           e  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                           s                      w                      w
# 1                           s                      w                      w
# 2                           s                      w                      w
# 3                           s                      w                      w
# 4                           s                      w                      w
# ...                       ...                    ...                    ...
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      veil-color ring-number ring-type spore-print-color population habitat  \
# 0             w           o         p                 k          s       u
# 1             w           o         p                 n          n       g
# 2             w           o         p                 n          n       m
# 3             w           o         p                 k          s       u
# 4             w           o         e                 n          a       g
# ...         ...         ...       ...               ...        ...     ...
# 8119          o           o         p                 b          c       l
# 8120          n           o         p                 b          v       l
# 8121          o           o         p                 b          c       l
# 8122          w           o         e                 w          v       l
# 8123          o           o         p                 o          c       l
#
#      poisonous
# 0            p
# 1            e
# 2            e
# 3            p
# 4            e
# ...        ...
# 8119         e
# 8120         e
# 8121         e
# 8122         p
# 8123         e
#
# [8124 rows x 22 columns]

# %%
new_data.dtypes
# Out:
# cap-shape                     object
# cap-surface                   object
# cap-color                     object
# bruises                       object
# odor                          object
# gill-attachment               object
# gill-spacing                  object
# gill-size                     object
# gill-color                    object
# stalk-shape                   object
# stalk-root                  category
# stalk-surface-above-ring      object
# stalk-surface-below-ring      object
# stalk-color-above-ring        object
# stalk-color-below-ring        object
# veil-color                    object
# ring-number                   object
# ring-type                     object
# spore-print-color             object
# population                    object
# habitat                       object
# poisonous                     object
# dtype: object

# %%
new_data["stalk-root"].unique()
# Out:
# ['e', 'c', 'b', 'r']
# Categories (4, object): ['b', 'c', 'e', 'r']

# %%
sns.countplot(data=new_data, x='stalk-root')
# Out:
# <Axes: xlabel='stalk-root', ylabel='count'>

# %%
new_data.isna().sum()
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# poisonous                   0
# dtype: int64

# %% [markdown]
# The missing values have been imputed and there are no missing values now.
#
# Let's move ahead and encode our categorical values.

# %% [markdown]
# let's check the number of unique caegories each column has.

# %%
for column in new_data.columns:
    print(column,new_data[column].nunique())
# Out:
# cap-shape 6
# cap-surface 4
# cap-color 10
# bruises 2
# odor 9
# gill-attachment 2
# gill-spacing 2
# gill-size 2
# gill-color 12
# stalk-shape 2
# stalk-root 4
# stalk-surface-above-ring 4
# stalk-surface-below-ring 4
# stalk-color-above-ring 9
# stalk-color-below-ring 9
# veil-color 4
# ring-number 3
# ring-type 5
# spore-print-color 9
# population 6
# habitat 7
# poisonous 2

# %% [markdown]
# We will map columns "poisonous". we are mapping poisonous column, so we can easily return the actual value during prediction.
# We will use get dumies for rest of the columns.

# %%
new_data["poisonous"] = new_data["poisonous"].map({"p" : 0, "e" : 1})

# %%
for column in new_data.drop(['poisonous'],axis=1).columns:
    new_data = pd.get_dummies(new_data, columns=[column], drop_first=True)

# %%
new_data
# Out:
#       poisonous  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 0             0        False        False        False        False
# 1             1        False        False        False        False
# 2             1        False        False        False        False
# 3             0        False        False        False        False
# 4             1        False        False        False        False
# ...         ...          ...          ...          ...          ...
# 8119          1        False        False         True        False
# 8120          1        False        False        False        False
# 8121          1        False         True        False        False
# 8122          0        False        False         True        False
# 8123          1        False        False        False        False
#
#       cap-shape_x  cap-surface_g  cap-surface_s  cap-surface_y  cap-color_c  \
# 0            True          False           True          False        False
# 1            True          False           True          False        False
# 2           False          False           True          False        False
# 3            True          False          False           True        False
# 4            True          False           True          False        False
# ...           ...            ...            ...            ...          ...
# 8119        False          False           True          False        False
# 8120         True          False           True          False        False
# 8121        False          False           True          False        False
# 8122        False          False          False           True        False
# 8123         True          False           True          False        False
#
#       ...  population_n  population_s  population_v  population_y  habitat_g  \
# 0     ...         False          True         False         False      False
# 1     ...          True         False         False         False       True
# 2     ...          True         False         False         False      False
# 3     ...         False          True         False         False      False
# 4     ...         False         False         False         False       True
# ...   ...           ...           ...           ...           ...        ...
# 8119  ...         False         False         False         False      False
# 8120  ...         False         False          True         False      False
# 8121  ...         False         False         False         False      False
# 8122  ...         False         False          True         False      False
# 8123  ...         False         False         False         False      False
#
#       habitat_l  habitat_m  habitat_p  habitat_u  habitat_w
# 0         False      False      False       True      False
# 1         False      False      False      False      False
# 2         False       True      False      False      False
# 3         False      False      False       True      False
# 4         False      False      False      False      False
# ...         ...        ...        ...        ...        ...
# 8119       True      False      False      False      False
# 8120       True      False      False      False      False
# 8121       True      False      False      False      False
# 8122       True      False      False      False      False
# 8123       True      False      False      False      False
#
# [8124 rows x 95 columns]

# %%
len(new_data.columns)
# Out:
# 95

# %% [markdown]
# As expected, the number of columns have increased because of get dummies.
#
# let's move ahead and check how balanced our data is:

# %%
sns.countplot(data=new_data, x='poisonous')
# Out:
# <Axes: xlabel='poisonous', ylabel='count'>

# %% [markdown]
# our dataset looks pretty balanced. So we are good to go with starting our model training!!!

# %% [markdown]
# # Model Training

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
#if there is only one label in y, then roc_auc_score returns error. We will use accuracy in that case
from sklearn.metrics import roc_auc_score, accuracy_score

# %%
X = new_data.drop(columns=['poisonous'])
X
# Out:
#       cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  cap-shape_x  \
# 0           False        False        False        False         True
# 1           False        False        False        False         True
# 2           False        False        False        False        False
# 3           False        False        False        False         True
# 4           False        False        False        False         True
# ...           ...          ...          ...          ...          ...
# 8119        False        False         True        False        False
# 8120        False        False        False        False         True
# 8121        False         True        False        False        False
# 8122        False        False         True        False        False
# 8123        False        False        False        False         True
#
#       cap-surface_g  cap-surface_s  cap-surface_y  cap-color_c  cap-color_e  \
# 0             False           True          False        False        False
# 1             False           True          False        False        False
# 2             False           True          False        False        False
# 3             False          False           True        False        False
# 4             False           True          False        False        False
# ...             ...            ...            ...          ...          ...
# 8119          False           True          False        False        False
# 8120          False           True          False        False        False
# 8121          False           True          False        False        False
# 8122          False          False           True        False        False
# 8123          False           True          False        False        False
#
#       ...  population_n  population_s  population_v  population_y  habitat_g  \
# 0     ...         False          True         False         False      False
# 1     ...          True         False         False         False       True
# 2     ...          True         False         False         False      False
# 3     ...         False          True         False         False      False
# 4     ...         False         False         False         False       True
# ...   ...           ...           ...           ...           ...        ...
# 8119  ...         False         False         False         False      False
# 8120  ...         False         False          True         False      False
# 8121  ...         False         False         False         False      False
# 8122  ...         False         False          True         False      False
# 8123  ...         False         False         False         False      False
#
#       habitat_l  habitat_m  habitat_p  habitat_u  habitat_w
# 0         False      False      False       True      False
# 1         False      False      False      False      False
# 2         False       True      False      False      False
# 3         False      False      False       True      False
# 4         False      False      False      False      False
# ...         ...        ...        ...        ...        ...
# 8119       True      False      False      False      False
# 8120       True      False      False      False      False
# 8121       True      False      False      False      False
# 8122       True      False      False      False      False
# 8123       True      False      False      False      False
#
# [8124 rows x 94 columns]

# %%
y = new_data['poisonous']
y
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 8119    1
# 8120    1
# 8121    1
# 8122    0
# 8123    1
# Name: poisonous, Length: 8124, dtype: int64

# %%
train_x, test_x, train_y, test_y = train_test_split(X,y, test_size=0.20,random_state=30)

# %%
clf = RandomForestClassifier()

# %% [markdown]
# ### Hyperparameter tuning

# %%
param_grid = {"n_estimators": [10, 50, 100, 130], "criterion": ['gini', 'entropy'],
                               "max_depth": range(2, 4, 1), "max_features": ['sqrt', 'log2']}

# %%
grid = GridSearchCV(estimator=clf,param_grid=param_grid,cv=5,verbose=3)

# %%
grid.fit(train_x,train_y)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.934 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.948 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.916 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.978 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.937 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.929 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.928 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.921 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.942 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.938 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.938 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.955 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.928 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.941 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.958 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.925 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.936 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.922 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.941 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.822 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.924 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.924 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.936 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=10;, score=0.876 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=50;, score=0.930 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=50;, score=0.927 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=50;, score=0.930 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=50;, score=0.907 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=50;, score=0.935 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.933 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.913 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.929 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=100;, score=0.926 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=130;, score=0.918 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=130;, score=0.935 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=130;, score=0.928 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=130;, score=0.938 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=2, max_features=log2, n_estimators=130;, score=0.931 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.952 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.965 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.953 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.974 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.982 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.971 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.962 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.969 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.979 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.955 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.975 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.963 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.978 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.975 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.989 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.974 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.980 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.988 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.985 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=10;, score=0.908 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=10;, score=0.925 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=10;, score=0.958 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=10;, score=0.956 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=10;, score=0.963 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=50;, score=0.959 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=50;, score=0.938 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=50;, score=0.942 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=50;, score=0.929 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=50;, score=0.965 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.935 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.958 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.962 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=100;, score=0.952 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=130;, score=0.942 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=130;, score=0.937 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=130;, score=0.959 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=130;, score=0.939 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=3, max_features=log2, n_estimators=130;, score=0.952 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.885 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.901 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.912 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.933 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=10;, score=0.900 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.932 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.927 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.938 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.940 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=50;, score=0.959 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.937 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.920 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.975 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.936 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.938 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.957 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.934 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.936 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=sqrt, n_estimators=130;, score=0.939 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=10;, score=0.915 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=10;, score=0.844 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=10;, score=0.885 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=10;, score=0.919 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=10;, score=0.859 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=50;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=50;, score=0.927 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=50;, score=0.932 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=50;, score=0.926 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=50;, score=0.938 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.912 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.919 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.933 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.936 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=100;, score=0.938 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=130;, score=0.921 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=130;, score=0.928 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=130;, score=0.930 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=130;, score=0.938 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=2, max_features=log2, n_estimators=130;, score=0.936 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.932 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.946 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.940 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.938 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=10;, score=0.968 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.946 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.961 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.971 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.949 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=50;, score=0.966 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.990 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.974 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.975 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.958 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=100;, score=0.941 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.988 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.983 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.964 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.992 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=sqrt, n_estimators=130;, score=0.992 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=10;, score=0.982 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=10;, score=0.872 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=10;, score=0.957 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=10;, score=0.941 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=10;, score=0.961 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=50;, score=0.933 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=50;, score=0.919 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=50;, score=0.937 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=50;, score=0.978 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.945 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.935 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.954 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.938 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=100;, score=0.941 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=130;, score=0.971 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=130;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=130;, score=0.954 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=130;, score=0.938 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=3, max_features=log2, n_estimators=130;, score=0.949 total time=   0.3s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 4),
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100, 130]},
#              verbose=3)

# %%
#extracting the best parameters
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'n_estimators': 130}

# %%
#creating a new model with the best parameters
random_forest = RandomForestClassifier(criterion='entropy',max_depth=3,max_features='sqrt',n_estimators=130)

# %%
# create best model for Random Forest
random_forest.fit(train_x,train_y)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=130)

# %%
# prediction using the Random Forest Algorithm
prediction_random_forest = random_forest.predict(test_x)
prediction_random_forest
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
# Accuracy test
# AUC for Random Forest
random_forest_score = roc_auc_score((test_y), prediction_random_forest) 
print('AUC for RF:' + str(random_forest_score))
# Out:
# AUC for RF:0.9832439678284182

# %%
# Saving the trained model
# Before any operation on the file, first we have to open the file
# wb means write into file in binary mode
# with statement ensures that the file is closed after execution of code inside the block
with open("trained_model.pickle", "wb") as file:
    pickle.dump(random_forest, file)

# %%
#Export new dataframe to csv file
new_data.to_csv("New_dataset/new_data.csv")
